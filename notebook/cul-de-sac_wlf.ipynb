# %% [markdown]
# # Symbolic computation of a cul de sac
#
# The three vector $A$, $B$, $C$ and $D$ defines a cul de sac. $I$ is the inner point of the intersection of the corridors. $Q$ is a vector which bissect the two segments

# %%
Q == X * Cos[t] + Y * Sin[t]
# Out:
# Q == X Cos[t] + Y Sin[t]

# %%
Solve[ Q == X * Cos[t] + Y * Sin[t], t]
# Out:
#                                                   2  2     2  2    4
#                                     Q X - Sqrt[-(Q  Y ) + X  Y  + Y ]
# {{t -> ConditionalExpression[ArcTan[---------------------------------,
#                                                   2    2
#                                                  X  + Y
#
#                  2               2   2    2    2
#               Q X      X Sqrt[-(Y  (Q  - X  - Y ))]
#          Q - ------- + ----------------------------
#               2    2              2    2
#              X  + Y              X  + Y
# >        ------------------------------------------] + 2 Pi C[1], C[1] ∈ Integers]},
#                              Y
#
#                                                      2  2     2  2    4
#                                        Q X + Sqrt[-(Q  Y ) + X  Y  + Y ]
# >   {t -> ConditionalExpression[ArcTan[---------------------------------,
#                                                      2    2
#                                                     X  + Y
#
#                  2               2   2    2    2
#               Q X      X Sqrt[-(Y  (Q  - X  - Y ))]
#          Q - ------- - ----------------------------
#               2    2              2    2
#              X  + Y              X  + Y
# >        ------------------------------------------] + 2 Pi C[1], C[1] ∈ Integers]}}
#                              Y

# %%
Az = {AzX, AzY, AzZ}
Ay = {AyX, AyY, AyZ}
B = {Bx, By, Bz}
# Out:
# {AzX, AzY, AzZ}
# {AyX, AyY, AyZ}
# {Bx, By, Bz}

# %%
res = Solve[ B == Az * Cos[t] + Ay * sin[t], t, Reals]
# Out:
# This system cannot be solved with the methods available to Solve.: This system cannot be solved with the methods available to Solve.
# Solve[{Bx, By, Bz} == {AzX Cos[t] + AyX sin[t], AzY Cos[t] + AyY sin[t],
#
# >     AzZ Cos[t] + AyZ sin[t]}, t, Reals]

# %%
res[[1]]
# Out:
# {Bx, By, Bz} == {AzX Cos[t] + AyX sin[t], AzY Cos[t] + AyY sin[t],
#
# >    AzZ Cos[t] + AyZ sin[t]}
